# %% [markdown]
# # clase 2

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
strImg = "foto1.jpg"
img = cv2.imread(strImg, cv2.IMREAD_GRAYSCALE)  #cuando sabermos que vamos a trabaja solo en grisse se agregar el parametro cv2.

# %%
plt.imshow(img, cmap="gray") #agregar el campo apra dfinir grises = camp
plt.show()

# %%
img.shape   #(734= alto, 1403=ancho,  3=referencia a 3 canales por que esta imagen es a color )
# Out:
# (410, 728)

# %%
# Dimensiones
alto = img.shape[0]
ancho = img. shape[1]

# %%
#Arreglos donde va estar la salida
ecualizada = np.zeros((alto, ancho, 1)) #matriz de cero alto y ancho de imagen origina y solo escala de grisis
frecuencias = np.zeros((256)) #arreglo, posicion de 0 a 256

# %%
for i in range(0, alto):
    for j in range(0, ancho):
        pixel = img[i, j]
        frecuencias[pixel] = frecuencias[pixel] + 1

# %%
densidad = np.true_divide(frecuencias, (alto*ancho))  #el total de pixeles

# %%
#hacemos la cdf
cdfFunc = np.cumsum(densidad, dtype=float)

# %%
frecuencias  #posiciones de 0 a 255
# Out:
# array([1.9771e+04, 5.7510e+03, 3.0070e+03, 2.2920e+03, 1.8350e+03,
#        1.7040e+03, 1.5280e+03, 1.3740e+03, 1.3310e+03, 1.2930e+03,
#        1.1490e+03, 1.1700e+03, 1.1810e+03, 1.2100e+03, 1.2750e+03,
#        1.3320e+03, 1.3570e+03, 1.3160e+03, 1.4180e+03, 1.4940e+03,
#        1.5360e+03, 1.4760e+03, 1.5580e+03, 1.5580e+03, 1.5620e+03,
#        1.5950e+03, 1.6250e+03, 1.7440e+03, 1.7170e+03, 1.7890e+03,
#        1.8100e+03, 1.7820e+03, 1.7900e+03, 1.8450e+03, 1.8210e+03,
#        1.7690e+03, 1.7180e+03, 1.6800e+03, 1.5640e+03, 1.4870e+03,
#        1.5690e+03, 1.5070e+03, 1.4470e+03, 1.5840e+03, 1.4970e+03,
#        1.5650e+03, 1.5550e+03, 1.5540e+03, 1.5330e+03, 1.5840e+03,
#        1.4620e+03, 1.3910e+03, 1.4830e+03, 1.6000e+03, 1.5260e+03,
#        1.4830e+03, 1.5650e+03, 1.5730e+03, 1.6010e+03, 1.6230e+03,
#        1.6640e+03, 1.7670e+03, 1.7740e+03, 1.8390e+03, 1.9120e+03,
#        1.9380e+03, 1.9540e+03, 2.0910e+03, 2.0530e+03, 2.0830e+03,
#        2.2780e+03, 2.2610e+03, 2.2470e+03, 2.1940e+03, 2.1890e+03,
#        2.1210e+03, 2.1760e+03, 2.1400e+03, 2.2020e+03, 2.1060e+03,
#        2.1970e+03, 2.0280e+03, 2.0120e+03, 2.0190e+03, 2.0460e+03,
#        1.9860e+03, 2.0400e+03, 1.9300e+03, 1.8690e+03, 1.9620e+03,
#        1.9800e+03, 1.8820e+03, 1.7740e+03, 1.7230e+03, 1.6840e+03,
#        1.5570e+03, 1.5260e+03, 1.5430e+03, 1.5200e+03, 1.4650e+03,
#        1.5440e+03, 1.5280e+03, 1.5440e+03, 1.5430e+03, 1.6820e+03,
#        1.7470e+03, 1.8780e+03, 1.7530e+03, 1.6260e+03, 1.5740e+03,
#        1.5560e+03, 1.5620e+03, 1.6730e+03, 1.7240e+03, 1.8300e+03,
#        7.10265344e-04, 6.53310105e-04, 7.80621817e-04, 7.57169660e-04,
#        6.06405789e-04, 6.56660413e-04, 6.46609488e-04, 6.83462879e-04,
#        7.37067810e-04, 6.60010721e-04, 6.39908872e-04, 6.13106406e-04,
#        7.00214420e-04, 6.33208255e-04, 6.56660413e-04, 7.77271509e-04,
#        7.30367194e-04, 6.80112570e-04, 6.70061646e-04, 7.00214420e-04,
#        7.37067810e-04, 7.57169660e-04, 8.54328598e-04, 7.57169660e-04,
#        7.20316269e-04, 8.50978290e-04, 7.20316269e-04, 7.47118735e-04,
#        8.54328598e-04, 8.81131064e-04, 9.41436612e-04, 9.41436612e-04,
#        9.91691236e-04, 1.15920665e-03, 1.08885017e-03, 1.15920665e-03,
#        1.33677298e-03, 1.37362637e-03, 1.76226213e-03, 1.84937014e-03,
#        2.25810775e-03, 2.71039936e-03, 3.22969713e-03, 3.06888234e-03,
#        3.11578665e-03, 3.46421871e-03, 3.28665237e-03, 3.18949343e-03,
#        4.18788529e-03, 7.49798982e-03, 1.21515679e-02, 4.20463683e-03,
#        2.10734388e-03, 1.13910480e-03, 2.11069418e-04, 6.03055481e-05,
#        3.35030823e-05, 2.01018494e-05, 1.34012329e-05, 1.00509247e-05,
#        1.67515411e-05, 3.35030823e-06, 1.00509247e-05, 3.35030823e-06,
#        6.70061646e-06, 0.00000000e+00, 0.00000000e+00, 6.70061646e-06,
#        0.00000000e+00, 3.35030823e-06, 3.35030823e-06, 1.00509247e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.68024658e-05])

# %%
cdfFunc  #su valor total es 1  # caso discrito
# Out:
# array([0.06623894, 0.08550657, 0.09558094, 0.10325985, 0.10940767,
#        0.11511659, 0.12023586, 0.12483919, 0.12929845, 0.13363039,
#        0.1374799 , 0.14139976, 0.14535647, 0.14941035, 0.15368199,
#        0.1581446 , 0.16269097, 0.16709997, 0.17185071, 0.17685607,
#        0.18200214, 0.1869472 , 0.19216698, 0.19738676, 0.20261994,
#        0.20796368, 0.21340793, 0.21925087, 0.22500335, 0.23099705,
#        0.23706111, 0.24303136, 0.24902841, 0.25520973, 0.26131064,
#        0.26723734, 0.27299317, 0.27862168, 0.28386157, 0.28884347,
#        0.29410011, 0.29914902, 0.30399692, 0.30930381, 0.31431922,
#        0.31956245, 0.32477218, 0.32997856, 0.33511458, 0.34042147,
#        0.34531962, 0.3499799 , 0.35494841, 0.3603089 , 0.36542147,
#        0.37038998, 0.37563321, 0.38090324, 0.38626709, 0.39170464,
#        0.39727955, 0.40319954, 0.40914299, 0.41530421, 0.42171   ,
#        0.42820289, 0.4347494 , 0.44175489, 0.44863307, 0.45561177,
#        0.46324377, 0.47081882, 0.47834696, 0.48569753, 0.49303136,
#        0.50013736, 0.50742763, 0.51459729, 0.52197467, 0.52903042,
#        0.53639105, 0.54318547, 0.54992629, 0.55669057, 0.5635453 ,
#        0.57019901, 0.57703364, 0.58349973, 0.58976146, 0.59633476,
#        0.60296837, 0.60927365, 0.6152171 , 0.62098968, 0.6266316 ,
#        0.63184803, 0.6369606 , 0.64213013, 0.64722259, 0.6521308 ,
#        0.65730367, 0.66242294, 0.66759582, 0.67276534, 0.67840056,
#        0.68425355, 0.69054543, 0.69641852, 0.70186612, 0.70713951,
#        0.71235259, 0.71758577, 0.72319083, 0.72896676, 0.73509783,
#        0.74093072, 0.74707853, 0.7533101 , 0.75897883, 0.76489547,
#        0.77089252, 0.77722795, 0.78302734, 0.78947668, 0.79588582,
#        0.8021509 , 0.80845283, 0.81430582, 0.82018226, 0.82560641,
#        0.83072233, 0.83491691, 0.83905454, 0.84279684, 0.84611029,
#        0.84903176, 0.85175556, 0.8543755 , 0.85697534, 0.85946797,
#        0.86183664, 0.86407129, 0.86623559, 0.86815867, 0.8700851 ,
#        0.87194452, 0.87384079, 0.87562316, 0.87730501, 0.87872889,
#        0.88023653, 0.88170062, 0.88314125, 0.88457518, 0.88596556,
#        0.88725543, 0.88843474, 0.8896978 , 0.89086706, 0.89196261,
#        0.89311847, 0.89421067, 0.89523586, 0.89626106, 0.8973164 ,
#        0.89827124, 0.89929979, 0.90015746, 0.90102854, 0.90193983,
#        0.90274725, 0.90356473, 0.90443916, 0.90523653, 0.9060004 ,
#        0.90683798, 0.90759515, 0.90835567, 0.90910949, 0.90977285,
#        0.91048311, 0.91113642, 0.91191705, 0.91267422, 0.91328062,
#        0.91393728, 0.91458389, 0.91526735, 0.91600442, 0.91666443,
#        0.91730434, 0.91791745, 0.91861766, 0.91925087, 0.91990753,
#        0.9206848 , 0.92141517, 0.92209528, 0.92276534, 0.92346556,
#        0.92420263, 0.9249598 , 0.92581412, 0.92657129, 0.92729161,
#        0.92814259, 0.92886291, 0.92961002, 0.93046435, 0.93134548,
#        0.93228692, 0.93322836, 0.93422005, 0.93537925, 0.93646811,
#        0.93762731, 0.93896408, 0.94033771, 0.94209997, 0.94394934,
#        0.94620745, 0.94891785, 0.95214755, 0.95521643, 0.95833222,
#        0.96179644, 0.96508309, 0.96827258, 0.97246047, 0.97995846,
#        0.99211002, 0.99631466, 0.998422  , 0.99956111, 0.99977218,
#        0.99983248, 0.99986599, 0.99988609, 0.99989949, 0.99990954,
#        0.99992629, 0.99992964, 0.99993969, 0.99994304, 0.99994975,
#        0.99994975, 0.99994975, 0.99995645, 0.99995645, 0.9999598 ,
#        0.99996315, 0.9999732 , 0.9999732 , 0.9999732 , 0.9999732 ,
#        1.        ])

# %%
for i in range(0, alto):
    for j in range(0, ancho):
        pixel = img[i, j]
        newPixel = 255*cdfFunc[pixel] #Ecualizacion  #trasnformar el pixel
        ecualizada[i, j] = round(newPixel, 0) # se redodnde para quitar los decimales

# %%
cv2.imwrite("ecualizada.jpg", ecualizada)
# Out:
# True

# %%
strImgEcualizada = "ecualizada.jpg"
imgEcualizada = cv2.imread(strImgEcualizada, cv2.IMREAD_GRAYSCALE)
plt.imshow(imgEcualizada, cmap="gray")
plt.show()

# %%
hist1 = cv2.calcHist([img], [0], None, [256], [0,256])
plt.plot(hist1, color="gray")
plt.xlabel("Intensidad de Pixeles")
plt.ylabel("Densidad")
plt.title("Imagen Original")
plt.show()

# %%
hist2 = cv2.calcHist([imgEcualizada], [0], None, [256], [0,256])
plt.plot(hist2, color="gray")
plt.xlabel("Intensidad de Pixeles")
plt.ylabel("Densidad")
plt.title("Imagen Original")
plt.show()
